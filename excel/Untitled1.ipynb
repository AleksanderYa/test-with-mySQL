# %%
from xls_function import create_infolist as create, search_xls

# %%
res = search_xls()
print(res)
full_base = []
# Out:
# Finded file --> Видаткова накладна № 276 від 11.02.2021.xls
# Видаткова накладна № 276 від 11.02.2021.xls
#
# Finded file --> Видаткова накладна № 786 від 22.05.2017 (3).xls
# Видаткова накладна № 786 від 22.05.2017 (3).xls
#
# Finded file --> Видаткова накладна № 572 від 20.03.2020.xls
# ./Новая папка/Видаткова накладна № 572 від 20.03.2020.xls
#
# Finded file --> Видаткова накладна № 1847 від 01.11.2019.xls
# ./Тертій О.В.ФОП\Накладные\2019/Видаткова накладна № 1847 від 01.11.2019.xls
#
# Finded file --> Видаткова накладна № 1891 від 11.11.2019.xls
# ./Тертій О.В.ФОП\Накладные\2019/Видаткова накладна № 1891 від 11.11.2019.xls
#
# Finded file --> Видаткова накладна № 1914 від 12.11.2019.xls
# ./Тертій О.В.ФОП\Накладные\2019/Видаткова накладна № 1914 від 12.11.2019.xls
#
# Finded file --> Видаткова накладна № 1954 від 18.11.2019.xls
# ./Тертій О.В.ФОП\Накладные\2019/Видаткова накладна № 1954 від 18.11.2019.xls
#
# Finded file --> Видаткова накладна № 2005 від 25.11.2019.xls
# ...

# %%
for i in res:
    prod2 = create(i)
    full_base.append(prod2)
#     print(prod2)
# Out:
# Connection succerfull
#
# all done.....base-list of product create
#
# Connection succerfull
#
# Connection succerfull
#
# All done...bayer and waybill add to list
#
# Connection succerfull
#
# all done.....base-list of product create
#
# Connection succerfull
#
# Connection succerfull
#
# All done...bayer and waybill add to list
#
# Connection succerfull
#
# all done.....base-list of product create
#
# Connection succerfull
#
# Connection succerfull
#
# All done...bayer and waybill add to list
#
# Connection succerfull
#
# all done.....base-list of product create
#
# Connection succerfull
#
# Connection succerfull
#
# All done...bayer and waybill add to list
#
# Connection succerfull
#
# all done.....base-list of product create
#
# Connection succerfull
#
# Connection succerfull
#
# All done...bayer and waybill add to list
#
# Connection succerfull
#
# all done.....base-list of product create
#
# Connection succerfull
#
# Connection succerfull
#
# ...

# %%
new_base = []
for i in full_base:
    if i:
        new_base.append(i)
        print(i)
        print()
# Out:
# [['Три ведмеді ТзОВ', 'Видаткова накладна № 276 від 11 лютого 2021 р.'], [1.0, 'Лецитин соєвий Adlec 2923 20 00 00', 400.0, 'кг', 36.2, 14480.0]]
#
# [['Три ведмеді ТзОВ', 'Видаткова накладна № 786 від 22 травня 2017 р.'], [1.0, 'какао-порошок  Schokinag S-85', 2.0, 'т', 65420.0, 130840.0], [2.0, 'Какао - терте Choco-Ivoire 1803100000', 0.5, 'т', 102000.0, 51000.0], [3.0, 'Какао-порошок  Schokinag, SN 10-12%  1805000010', 1.0, 'т', 61250.0, 61250.0]]
#
# [['Товариство з обмеженою відповідальністю  "Дід Сергій"', 'Видаткова накладна № 572 від 20 березня 2020 р.'], [1.0, 'какао-порошок JB-800', 0.025, 'т', 71000.0, 1775.0], [2.0, 'какао-порошок JB-800', 0.025, 'т', 71000.0, 1775.0], [3.0, 'какао-порошок JB-800', 0.025, 'т', 71000.0, 1775.0], [4.0, 'какао-порошок JB-800', 0.025, 'т', 71000.0, 1775.0], [5.0, 'какао-порошок JB-800', 0.025, 'т', 71000.0, 1775.0]]
#
# ...

# %%
print(len(full_base))
print(len(new_base))
# Out:
# 114
# 114
